# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here\'s a detailed outline for a blog post on the "Rise of AI in India," designed to be comprehensive, engaging, and informative.\n\n---\n\n## Blog Title Options:\n*   **The AI Awakening: How India is Redefining the Global AI Landscape**\n*   **From Code to Culture: The Unstoppable Rise of AI in India**\n*   **India\'s AI Revolution: Opportunities, Challenges, and the Road Ahead**\n*   **Decoding India\'s AI Ambition: A Deep Dive into its Transformative Journey**\n\n---\n\n### **I. Introduction: The Dawn of a New Era**\n\n*   **A. Catchy Hook:** Start with a compelling statistic about AI\'s global impact or a fascinating AI application that resonates with readers. Immediately pivot to India.\n    *   *Example:* "From powering your personalized recommendations to revolutionizing healthcare, Artificial Intelligence is no longer a futuristic concept – it\'s here, and nowhere is its ascent more dynamic than in India."\n*   **B. Defining AI (Briefly):** Explain what AI is in simple terms, moving beyond the sci-fi robots to practical applications like machine learning, deep learning, and natural language processing.\n*   **C. India\'s Unique Position:** Introduce India as a rapidly emerging global AI hub, highlighting its unique blend of technological prowess, massive data generation, and diverse problems ripe for AI solutions.\n*   **D. Blog Thesis/Roadmap:** Briefly state what the blog will cover – the drivers, applications, opportunities, and challenges of AI\'s rise in India.\n\n---\n\n### **II. The Genesis: Why India is Ripe for AI Adoption**\n\n*   **A. Demographic Dividend & Talent Pool:**\n    *   India\'s vast young, tech-savvy population.\n    *   High number of STEM graduates.\n    *   Growing pool of data scientists, AI/ML engineers.\n*   **B. Digital India & Data Explosion:**\n    *   Massive digital adoption (Jio effect, UPI, Aadhaar).\n    *   Unprecedented data generation across sectors (consumer, financial, health).\n    *   This data is the "fuel" for AI.\n*   **C. Government Vision & Policy Push:**\n    *   **"AI for All" philosophy:** NITI Aayog\'s national strategy.\n    *   **IndiaAI Initiative:** Focus on compute infrastructure, data, talent, and responsible AI.\n    *   "Digital India" and "Make in India" initiatives providing foundational support.\n*   **D. Cost-Effectiveness & Innovation Hub:**\n    *   Lower operational costs compared to Western nations.\n    *   Strong startup ecosystem fostering innovation and agile development.\n*   **E. Solving Unique Indian Problems:**\n    *   AI\'s potential to address large-scale social challenges (e.g., healthcare access, agricultural efficiency, financial inclusion).\n\n---\n\n### **III. AI in Action: Sectoral Impact & Key Applications**\n\n*   **A. Healthcare Transformation:**\n    *   **Diagnostics:** AI-powered image analysis (X-rays, MRIs) for early disease detection (e.g., retinopathy, cancer).\n    *   **Drug Discovery:** Accelerating research and development of new medicines.\n    *   **Personalized Medicine:** Tailoring treatments based on patient data.\n    *   **Telemedicine & Remote Monitoring:** Expanding access to healthcare in rural areas.\n*   **B. Fintech & Financial Inclusion:**\n    *   **Fraud Detection:** Real-time anomaly detection in transactions.\n    *   **Personalized Banking:** Customized financial products and advice.\n    *   **Credit Scoring:** Expanding credit access to underserved populations using alternative data.\n    *   **Robo-Advisors & Chatbots:** Enhancing customer service and investment guidance.\n*   **C. Agriculture & Rural Development:**\n    *   **Crop Yield Optimization:** Predicting harvests, advising on optimal planting/harvesting times.\n    *   **Pest & Disease Detection:** Early identification through image analysis.\n    *   **Weather Forecasting:** Hyper-local predictions for farmers.\n    *   **Supply Chain Optimization:** Reducing food waste.\n*   **D. Education & S ...

# %%
print(final_state['outline'])
# Out:
# Here's a detailed outline for a blog post on the "Rise of AI in India," designed to be comprehensive, engaging, and informative.
#
# ---
#
# ## Blog Title Options:
# *   **The AI Awakening: How India is Redefining the Global AI Landscape**
# *   **From Code to Culture: The Unstoppable Rise of AI in India**
# *   **India's AI Revolution: Opportunities, Challenges, and the Road Ahead**
# *   **Decoding India's AI Ambition: A Deep Dive into its Transformative Journey**
#
# ---
#
# ### **I. Introduction: The Dawn of a New Era**
#
# *   **A. Catchy Hook:** Start with a compelling statistic about AI's global impact or a fascinating AI application that resonates with readers. Immediately pivot to India.
#     *   *Example:* "From powering your personalized recommendations to revolutionizing healthcare, Artificial Intelligence is no longer a futuristic concept – it's here, and nowhere is its ascent more dynamic than in India."
# *   **B. Defining AI (Briefly):** Explain what AI is in simple terms, moving beyond the sci-fi robots to practical applications like machine learning, deep learning, and natural language processing.
# *   **C. India's Unique Position:** Introduce India as a rapidly emerging global AI hub, highlighting its unique blend of technological prowess, massive data generation, and diverse problems ripe for AI solutions.
# *   **D. Blog Thesis/Roadmap:** Briefly state what the blog will cover – the drivers, applications, opportunities, and challenges of AI's rise in India.
#
# ---
#
# ### **II. The Genesis: Why India is Ripe for AI Adoption**
#
# *   **A. Demographic Dividend & Talent Pool:**
#     *   India's vast young, tech-savvy population.
#     *   High number of STEM graduates.
#     *   Growing pool of data scientists, AI/ML engineers.
# *   **B. Digital India & Data Explosion:**
#     *   Massive digital adoption (Jio effect, UPI, Aadhaar).
#     *   Unprecedented data generation across sectors (consumer, financial, health).
#     *   This data is the "fuel" for AI.
# *   **C. Government Vision & Policy Push:**
#     *   **"AI for All" philosophy:** NITI Aayog's national strategy.
#     *   **IndiaAI Initiative:** Focus on compute infrastructure, data, talent, and responsible AI.
#     *   "Digital India" and "Make in India" initiatives providing foundational support.
# *   **D. Cost-Effectiveness & Innovation Hub:**
#     *   Lower operational costs compared to Western nations.
#     *   Strong startup ecosystem fostering innovation and agile development.
# *   **E. Solving Unique Indian Problems:**
#     *   AI's potential to address large-scale social challenges (e.g., healthcare access, agricultural efficiency, financial inclusion).
#
# ---
#
# ### **III. AI in Action: Sectoral Impact & Key Applications**
#
# *   **A. Healthcare Transformation:**
#     *   **Diagnostics:** AI-powered image analysis (X-rays, MRIs) for early disease detection (e.g., retinopathy, cancer).
#     *   **Drug Discovery:** Accelerating research and development of new medicines.
#     *   **Personalized Medicine:** Tailoring treatments based on patient data.
#     *   **Telemedicine & Remote Monitoring:** Expanding access to healthcare in rural areas.
# *   **B. Fintech & Financial Inclusion:**
#     *   **Fraud Detection:** Real-time anomaly detection in transactions.
#     *   **Personalized Banking:** Customized financial products and advice.
#     *   **Credit Scoring:** Expanding credit access to underserved populations using alternative data.
#     *   **Robo-Advisors & Chatbots:** Enhancing customer service and investment guidance.
# *   **C. Agriculture & Rural Development:**
#     *   **Crop Yield Optimization:** Predicting harvests, advising on optimal planting/harvesting times.
#     *   **Pest & Disease Detection:** Early identification through image analysis.
#     *   **Weather Forecasting:** Hyper-local predictions for farmers.
#     *   **Supply Chain Optimization:** Reducing food waste.
# *   **D. Education & Skill Development:**
#     *   **Personalized Learning:** Adaptive platforms tailored to individual student needs.
#     *   **Smart Content Creation:** Automating educational material generation.
#     *   **Virtual Tutors & Language Learning:** Expanding access to quality education.
# *   **E. E-commerce & Retail:**
#     *   **Recommendation Engines:** Personalized product suggestions.
#     *   **Logistics & Supply Chain:** Optimizing delivery routes and inventory management.
#     *   **Customer Service:** AI-powered chatbots and virtual assistants.
# *   **F. Public Services & Governance:**
#     *   **Smart Cities:** Traffic management, waste management, public safety.
#     *   **Citizen Services:** Improving efficiency of government portals and grievance redressal.
#
# ---
#
# ### **IV. Opportunities & Benefits: The Promise of AI for India**
#
# *   **A. Economic Growth & Job Creation:**
#     *   Contribution to GDP (NASSCOM projections).
#     *   Creation of new job roles (AI engineers, data scientists, ethicists).
#     *   Increased productivity across industries.
# *   **B. Innovation & Global Leadership:**
#     *   Opportunity to become a global hub for AI research and development.
#     *   Solving complex, unique problems that can be scaled globally.
# *   **C. Social Inclusion & Empowerment:**
#     *   Bridging gaps in access to healthcare, education, and financial services.
#     *   Empowering marginalized communities through AI-driven solutions.
# *   **D. Enhanced Efficiency & Productivity:**
#     *   Streamlining operations in businesses and government.
#     *   Automating repetitive tasks, freeing up human potential for higher-value work.
#
# ---
#
# ### **V. Challenges & Considerations: Navigating the Road Ahead**
#
# *   **A. Job Displacement & Skilling Gap:**
#     *   Fear of automation replacing human jobs.
#     *   Need for massive reskilling and upskilling initiatives.
#     *   Importance of focusing on "human-AI collaboration."
# *   **B. Data Privacy & Security Concerns:**
#     *   Managing vast amounts of sensitive personal data.
#     *   Developing robust data governance frameworks and regulations.
#     *   Preventing data breaches and misuse.
# *   **C. Ethical AI & Bias:**
#     *   Ensuring fairness, transparency, and accountability in AI systems.
#     *   Addressing algorithmic bias that could perpetuate social inequalities.
#     *   Need for diverse teams in AI development.
# *   **D. Infrastructure & Connectivity:**
#     *   Bridging the digital divide, especially in rural areas.
#     *   Ensuring reliable high-speed internet access.
#     *   Need for robust compute infrastructure (data centers, cloud).
# *   **E. Regulatory Framework & Policy Evolution:**
#     *   Developing clear, agile, and forward-looking AI policies.
#     *   Balancing innovation with regulation.
#     *   International collaboration on AI governance.
# *   **F. Talent Retention & Brain Drain:**
#     *   Competing with global tech giants for top AI talent.
#     *   Creating attractive opportunities to retain skilled professionals in India.
#
# ---
#
# ### **VI. Conclusion: India's AI Odyssey – A Balanced Future**
#
# *   **A. Recap of Key Points:** Briefly reiterate India's unique position, the breadth of AI applications, and the dual nature of opportunities and challenges.
# *   **B. The Path Forward:** Emphasize the need for:
#     *   Continued government support and strategic investment.
#     *   Stronger industry-academia collaboration.
#     *   Focus on responsible and ethical AI development.
#     *   Prioritizing skill development and lifelong learning.
# *   **C. Vision for the Future:** Paint an optimistic yet realistic picture of India's potential to not just adopt, but lead the global AI narrative, leveraging it for inclusive growth and societal good.
# *   **D. Call to Action/Thought-Provoking Question:**
#     *   *Example:* "As India stands on the precipice of this AI revolution, the collective efforts of policymakers, innovators, educators, and citizens will determine whether we harness its full potential to build a more intelligent, equitable, and prosperous future for all. What role will *you* play in this journey?"
#
# ---
#
# ### **VII. Blog Post Enhancements (Not part of the outline, but good for the blog):**
#
# *   **Keywords:** AI in India, India AI, Artificial Intelligence India, AI applications India, Indian startups AI, NITI Aayog AI, Digital India, AI challenges India, AI opportunities India, India tech.
# *   **Target Audience:** General public, business professionals, tech enthusiasts, policymakers, students.
# *   **Tone:** Informative, optimistic, balanced, forward-looking.
# *   **Visuals:** Infographics showing growth statistics, images of AI applications in India (e.g., agricultural tech, healthcare diagnostics), charts on investment trends.
# *   **Internal Links:** Link to relevant government reports, startup success stories, or specific AI projects mentioned.
# *   **External Links:** Link to reputable sources for statistics or deeper dives into specific topics.

# %%
print(final_state['content'])
# Out:
# Here's a detailed blog post based on your comprehensive outline:
#
# ---
#
# ## India's AI Revolution: Opportunities, Challenges, and the Road Ahead
#
# From powering your personalized recommendations to revolutionizing healthcare, Artificial Intelligence is no longer a futuristic concept – it's here, and nowhere is its ascent more dynamic than in India. Once seen primarily as an IT services hub, India is rapidly emerging as a global AI powerhouse, poised to leverage this transformative technology for unprecedented economic growth and societal good.
#
# At its core, AI encompasses systems that can learn from data, make predictions, and understand human language, moving far beyond the realm of sci-fi robots. It includes sophisticated fields like machine learning (ML), deep learning (DL), and natural language processing (NLP), which are now finding practical applications across every facet of our lives. India, with its unique blend of technological prowess, massive data generation, and a multitude of diverse challenges ripe for AI solutions, stands at the precipice of an AI revolution.
#
# This blog post will delve into the compelling drivers behind India's AI surge, explore its transformative applications across key sectors, weigh the immense opportunities it presents, and candidly address the challenges that must be navigated for a truly intelligent and inclusive future.
#
# ---
#
# ### The Genesis: Why India is Ripe for AI Adoption
#
# India's journey towards AI leadership isn't accidental; it's the culmination of several converging factors that create a uniquely fertile ground for AI adoption and innovation.
#
# **A. Demographic Dividend & Talent Pool:** India boasts one of the world's largest young, tech-savvy populations. With a staggering number of STEM graduates entering the workforce each year, the nation is rapidly building a formidable talent pool of data scientists, AI/ML engineers, and researchers. This human capital is the intellectual engine driving India's AI ambitions.
#
# **B. Digital India & Data Explosion:** Initiatives like "Digital India" have democratized digital access, fueled by the "Jio effect" which brought affordable internet to millions. The widespread adoption of platforms like UPI (Unified Payments Interface) and Aadhaar has led to an unprecedented explosion of digital data across consumer, financial, and health sectors. This data, often referred to as the "new oil," is the essential fuel for training and developing robust AI models.
#
# **C. Government Vision & Policy Push:** The Indian government has demonstrated a clear, forward-looking vision for AI. NITI Aayog's "AI for All" philosophy underpins a national strategy aimed at leveraging AI for inclusive growth. More recently, the "IndiaAI Initiative" has been launched to focus on critical pillars: building robust compute infrastructure, ensuring data accessibility, fostering talent development, and promoting responsible AI practices. Foundational initiatives like "Make in India" further bolster the ecosystem for domestic AI development.
#
# **D. Cost-Effectiveness & Innovation Hub:** Compared to many Western nations, India offers lower operational costs, making it an attractive destination for AI research and development. This, coupled with a vibrant and agile startup ecosystem, fosters rapid innovation and experimentation, allowing new AI solutions to be developed and deployed at scale.
#
# **E. Solving Unique Indian Problems:** Perhaps most compelling is AI's potential to address India's unique, large-scale social challenges. From improving healthcare access in remote villages to enhancing agricultural efficiency for millions of farmers and expanding financial inclusion for the unbanked, AI offers scalable solutions to complex problems that can significantly improve the lives of its citizens.
#
# ---
#
# ### AI in Action: Sectoral Impact & Key Applications
#
# The transformative power of AI is already being felt across diverse sectors in India, reshaping industries and improving daily lives.
#
# **A. Healthcare Transformation:**
# *   **Diagnostics:** AI-powered image analysis is revolutionizing early disease detection, assisting doctors in identifying conditions like diabetic retinopathy, various cancers, and neurological disorders from X-rays, MRIs, and CT scans with remarkable accuracy.
# *   **Drug Discovery:** AI algorithms are accelerating the research and development of new medicines by predicting molecular interactions and optimizing drug compounds, significantly reducing the time and cost involved.
# *   **Personalized Medicine:** By analyzing vast patient data, AI can help tailor treatments, predict patient responses, and optimize dosages for more effective and individualized healthcare.
# *   **Telemedicine & Remote Monitoring:** AI-powered platforms are expanding access to healthcare in rural areas, enabling remote consultations, monitoring chronic conditions, and providing timely medical advice.
#
# **B. Fintech & Financial Inclusion:**
# *   **Fraud Detection:** AI algorithms can detect real-time anomalies in transactions, flagging suspicious activities and significantly reducing financial fraud.
# *   **Personalized Banking:** AI helps banks offer customized financial products, investment advice, and credit solutions tailored to individual customer needs and risk profiles.
# *   **Credit Scoring:** By analyzing alternative data sources, AI is expanding credit access to underserved populations, allowing individuals without traditional credit histories to secure loans.
# *   **Robo-Advisors & Chatbots:** AI-powered robo-advisors provide automated investment guidance, while chatbots enhance customer service by resolving queries quickly and efficiently.
#
# **C. Agriculture & Rural Development:**
# *   **Crop Yield Optimization:** AI models analyze soil data, weather patterns, and historical yields to advise farmers on optimal planting times, crop selection, and irrigation strategies, boosting productivity.
# *   **Pest & Disease Detection:** Drones equipped with AI-powered cameras can identify early signs of pest infestations or crop diseases, allowing for timely intervention and minimizing losses.
# *   **Weather Forecasting:** Hyper-local, accurate weather predictions powered by AI enable farmers to make informed decisions about their agricultural activities.
# *   **Supply Chain Optimization:** AI helps streamline the agricultural supply chain, reducing food waste and ensuring produce reaches markets efficiently.
#
# **D. Education & Skill Development:**
# *   **Personalized Learning:** Adaptive AI platforms tailor educational content and pace to individual student needs, identifying knowledge gaps and recommending targeted learning paths.
# *   **Smart Content Creation:** AI can automate the generation of educational materials, quizzes, and summaries, freeing up educators' time.
# *   **Virtual Tutors & Language Learning:** AI-powered virtual tutors and language learning apps provide accessible, interactive learning experiences, democratizing quality education.
#
# **E. E-commerce & Retail:**
# *   **Recommendation Engines:** AI drives personalized product suggestions, enhancing the shopping experience and boosting sales for e-commerce giants.
# *   **Logistics & Supply Chain:** AI optimizes delivery routes, manages inventory, and predicts demand, leading to more efficient and cost-effective operations.
# *   **Customer Service:** AI-powered chatbots and virtual assistants handle customer queries, provide support, and resolve issues 24/7, improving customer satisfaction.
#
# **F. Public Services & Governance:**
# *   **Smart Cities:** AI is crucial for optimizing urban infrastructure, from intelligent traffic management systems and waste management to enhancing public safety through surveillance analytics.
# *   **Citizen Services:** AI improves the efficiency of government portals, streamlines grievance redressal mechanisms, and helps in the delivery of various public services.
#
# ---
#
# ### Opportunities & Benefits: The Promise of AI for India
#
# The widespread adoption of AI promises a paradigm shift for India, unlocking immense opportunities and benefits.
#
# **A. Economic Growth & Job Creation:** AI is projected to contribute significantly to India's GDP, with NASSCOM estimating it could add over $500 billion to the economy by 2025. While some jobs may be automated, AI is also creating entirely new job roles – from AI engineers and data scientists to AI ethicists and trainers – and increasing productivity across industries.
#
# **B. Innovation & Global Leadership:** India has the unique opportunity to become a global hub for AI research and development, particularly in areas like responsible AI and AI for social good. By solving complex, unique problems within its borders, India can develop scalable AI solutions that have global applicability, cementing its position as an innovation leader.
#
# **C. Social Inclusion & Empowerment:** AI has the potential to bridge critical gaps in access to healthcare, education, and financial services, particularly for marginalized and rural communities. It can empower individuals with disabilities, provide personalized learning for underprivileged students, and extend financial tools to the unbanked, fostering a more equitable society.
#
# **D. Enhanced Efficiency & Productivity:** Across businesses and government, AI can streamline operations, automate repetitive tasks, and provide data-driven insights, freeing up human potential for higher-value, creative, and strategic work. This surge in efficiency translates directly into improved service delivery and economic competitiveness.
#
# ---
#
# ### Challenges & Considerations: Navigating the Road Ahead
#
# While the promise of AI for India is immense, the path forward is not without its hurdles. Navigating these challenges responsibly will be crucial for realizing AI's full potential.
#
# **A. Job Displacement & Skilling Gap:** A pervasive fear is that automation will displace human jobs, particularly in sectors with repetitive tasks. This necessitates massive reskilling and upskilling initiatives to prepare the workforce for new roles and foster "human-AI collaboration" rather than replacement.
#
# **B. Data Privacy & Security Concerns:** The sheer volume of sensitive personal data required to train AI models raises significant privacy and security concerns. India needs robust data governance frameworks, clear regulations, and stringent security protocols to prevent data breaches and misuse, building public trust.
#
# **C. Ethical AI & Bias:** AI systems learn from the data they are fed. If this data is biased, the AI will perpetuate and even amplify existing societal inequalities. Ensuring fairness, transparency, and accountability in AI systems is paramount. This requires diverse teams in AI development and proactive measures to identify and mitigate algorithmic bias.
#
# **D. Infrastructure & Connectivity:** Despite rapid advancements, a significant digital divide persists, especially in rural areas. Bridging this gap by ensuring reliable high-speed internet access and building robust compute infrastructure (data centers, cloud capabilities) is essential for equitable AI adoption.
#
# **E. Regulatory Framework & Policy Evolution:** Developing clear, agile, and forward-looking AI policies that balance innovation with necessary regulation is a complex task. India needs to formulate a comprehensive regulatory framework that addresses emerging issues like liability, intellectual property, and data governance, while also collaborating internationally on AI governance standards.
#
# **F. Talent Retention & Brain Drain:** Competing with global tech giants for top AI talent remains a challenge. India must create attractive opportunities, foster a world-class research environment, and offer competitive compensation to retain its skilled professionals and prevent a brain drain.
#
# ---
#
# ### Conclusion: India's AI Odyssey – A Balanced Future
#
# India's AI odyssey is well underway, characterized by a unique confluence of demographic advantages, digital infrastructure, proactive government policies, and a vibrant innovation ecosystem. From transforming healthcare and finance to revolutionizing agriculture and public services, AI is proving to be a powerful catalyst for change, promising significant economic growth and social inclusion.
#
# However, realizing this ambitious vision requires a concerted, multi-pronged approach. Continued government support and strategic investment in research and infrastructure are vital. Stronger industry-academia collaboration is needed to bridge the gap between theoretical knowledge and practical application. Crucially, India must prioritize the development of responsible and ethical AI, ensuring that these powerful technologies serve humanity and do not exacerbate existing disparities. Finally, a relentless focus on skill development and lifelong learning will empower its vast workforce to thrive in an AI-driven future.
#
# As India stands on the precipice of this AI revolution, the collective efforts of policymakers, innovators, educators, and citizens will determine whether we harness its full potential to build a more intelligent, equitable, and prosperous future for all. What role will *you* play in this journey?
#
# ---
